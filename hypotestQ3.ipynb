# %% [markdown]
# <a href="https://colab.research.google.com/github/sailu708d/hypotestQ3.ipynb/blob/main/hypotestQ3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from scipy import stats
from scipy.stats import norm
from scipy.stats import chi2_contingency

# %%
data = pd.read_csv('BuyerRatio.csv')
data
# Out:
#   Observed Values  East  West  North  South
# 0           Males    50   142    131     70
# 1         Females   435  1523   1356    750

# %%
obs=np.array([[50,142,131,80],[435,1523,1356,750]])
obs
# Out:
# array([[  50,  142,  131,   80],
#        [ 435, 1523, 1356,  750]])

# %%
chi2_contingency(obs)
# Out:
# Chi2ContingencyResult(statistic=1.9392327185592513, pvalue=0.5851144752312325, dof=3, expected_freq=array([[  43.75531677,  150.21155138,  134.15289904,   74.88023282],
#        [ 441.24468323, 1514.78844862, 1352.84710096,  755.11976718]]))
